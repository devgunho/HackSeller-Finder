# %%
# %load_ext autoreload
# %autoreload 2
import aspect_based_sentiment_analysis as absa

# %%
recognizer = absa.aux_models.BasicPatternRecognizer()
nlp = absa.load('absa/classifier-rest-0.2', pattern_recognizer=recognizer)
text = ('Battlegrounds hacks will take you far, but a great drop will help kick it up a notch. There are a lot of things to remember when it comes to players PUBG, but knowing the map will always remain a top priority. Well, that and ensuring that youve got the best playerunkowns battlegrounds hack on your side.')
completed_task = nlp(text, aspects=['battlegrounds', 'hack'])
battlegrounds, hack = completed_task.examples
absa.summary(battlegrounds)
absa.summary(hack)
absa.display(battlegrounds.review)
absa.display(hack.review)
# Out:
# Sentiment.positive for "battlegrounds"
# Scores (neutral/negative/positive): [0.059 0.049 0.892]
# Sentiment.positive for "hack"
# Scores (neutral/negative/positive): [0.116 0.335 0.549]
# ...

# %%
recognizer = absa.aux_models.BasicPatternRecognizer()
nlp = absa.load('absa/classifier-rest-0.2', pattern_recognizer=recognizer)
text = ('Playerunknown Battlegrounds Hacks - How we keep them safe. ... Always be on the lookout if hack providers are the real deal, and also never download free pubg cheats from a forum. ... An aimbot is a tool that allows you to shoot your enemies without having to aim manually. It helps you to shoot more accurately with less skill.')
completed_task = nlp(text, aspects=['battlegrounds', 'hack'])
battlegrounds, hack = completed_task.examples
absa.summary(battlegrounds)
absa.summary(hack)
absa.display(battlegrounds.review)
absa.display(hack.review)
# Out:
# Sentiment.positive for "battlegrounds"
# Scores (neutral/negative/positive): [0.002 0.002 0.997]
# Sentiment.positive for "hack"
# Scores (neutral/negative/positive): [0.002 0.004 0.994]
# ...

# %%
# hack 13 - https://gamestwister.com/
recognizer = absa.aux_models.BasicPatternRecognizer()
nlp = absa.load('absa/classifier-rest-0.2', pattern_recognizer=recognizer)
text = ('Undetected PUBG Hacks for Steam, Kakao, Gameloop and Lite versions of PUBG. Get access and start dominate right now! Safe aimbot and esp cheats.')
completed_task = nlp(text, aspects=['battlegrounds', 'hack'])
battlegrounds, hack = completed_task.examples
absa.summary(battlegrounds)
absa.summary(hack)
absa.display(battlegrounds.review)
absa.display(hack.review)
# Out:
# Sentiment.positive for "battlegrounds"
# Scores (neutral/negative/positive): [0.029 0.053 0.917]
# Sentiment.positive for "hack"
# Scores (neutral/negative/positive): [0.041 0.034 0.925]
# ...

# %%
# hack 9 - https://www.hack-cheat.org/
recognizer = absa.aux_models.BasicPatternRecognizer()
nlp = absa.load('absa/classifier-rest-0.2', pattern_recognizer=recognizer)
text = ('GFX Tool for BattleGrounds (NEW) V.18 tricks hints guides reviews promo codes easter eggs and more for android application. Avoid GFX Tool for BattleGrounds (NEW) V.18 hack cheats for your own safety, choose our tips and advices confirmed by pro players, testers and users like you. Ask a question or add answers, watch video tutorials & submit own opinion about this game/app.')
completed_task = nlp(text, aspects=['battlegrounds', 'hack'])
battlegrounds, hack = completed_task.examples
absa.summary(battlegrounds)
absa.summary(hack)
absa.display(battlegrounds.review)
absa.display(hack.review)
# Out:
# Sentiment.negative for "battlegrounds"
# Scores (neutral/negative/positive): [0.347 0.374 0.279]
# Sentiment.negative for "hack"
# Scores (neutral/negative/positive): [0.026 0.819 0.155]
# ...

# %%
# hack 8 - 
recognizer = absa.aux_models.BasicPatternRecognizer()
nlp = absa.load('absa/classifier-rest-0.2', pattern_recognizer=recognizer)
text = ('Download or share your PlayerUnknowns Battlegrounds hack at worlds leading forum for all kind of PlayerUnknowns Battlegrounds hacks, cheats and aimbots. Here you will find a list of discussions in the PlayerUnknows Battlegrounds forum at the Popular Games category. Sub-Forums : PlayerUnknowns Battlegrounds.')
completed_task = nlp(text, aspects=['battlegrounds', 'hack'])
battlegrounds, hack = completed_task.examples
absa.summary(battlegrounds)
absa.summary(hack)
absa.display(battlegrounds.review)
absa.display(hack.review)
# Out:
# Sentiment.positive for "battlegrounds"
# Scores (neutral/negative/positive): [0.094 0.008 0.897]
# Sentiment.positive for "hack"
# Scores (neutral/negative/positive): [0.111 0.027 0.861]
# ...
